# %% [markdown]
# Every week there will be coding and writing exercises on the contents seen in the lecture. These exercises will be solved before the lecture of the following week. Finally, the last exercies will be on the material to be taught in the following week (and will be addressed during that lecture), so feel free to give it a try!
#
# This is the Jupyter notebook of MMLO's week 4. In Exercise 1, you are asked to identify the vertices of the polyhedron of a LP problem. In Exercise 2, you need to find the basic feasible solutions of a LP problem and perform the simplex method graphically. Finally, in Exercise 3 you are asked to work with the constraints of an LP problem to improve the upper bound on the problem.
#
# We recommend the step-by-step guide provided by JuMP (https://jump.dev/JuMP.jl/stable/tutorials/getting_started/getting_started_with_JuMP/#Step-by-step) to know more about how to write and solve optimization problems in Julia.

# %%
using JuMP
using HiGHS

# %% [markdown]
# # Exercise 1

# %% [markdown]
# Consider the LP problem of exercise 3 of Week's in standard form:
# $$
#     \begin{align} \\
#         \text{max }  & 4x_1 + 14x_2 \\
#         \text{subject to } & 2x_1 + 7x_2 + x_3 = 21 \\
#          & 7x_1 + 2x_2 + x_4 =  21 \\
#          & x_1, x_2, x_3, x_4 \geq 0
#     \end{align}
# $$

# %% [markdown]
# Answer to the following questions.

# %% [markdown]
# 1. Find all the vertices of the polyhedron in standard form. You can use an online calculator to find the inverse of the matrices (e.g., https://www.wolframalpha.com/input).

# %% [markdown]
# 2. Evaluate the objective function at each vertex of the polyhedron. What is the optimal value of the objective function?

# %% [markdown]
# 3. Code the problem in Julia and solve it. What is the optimal solution reported by the HiGHS solver?

# %% [markdown]
# # Exercise 2

# %% [markdown]
# Answer to the following questions.

# %% [markdown]
# 1. Consider the polygon (polyhedron) $S = \{ (x_1, x_2)^{\text{T}} | x_1 + x_2 \leq 1, x_1 - x_2 \leq 1, x_1 \geq 0, x_2 \geq 0\}$ associated with a certain LP. Find all the basic feasible solutions.

# %% [markdown]
# 2. Draw the polyhedron $S$ of the previous question and identify its vertices. How are they related to the basic feasible solutions calculated in the previous question?

# %% [markdown]
# # Exercise 3

# %% [markdown]
# Consider the following LP problem $(P_1)$:
# $$
#     \begin{align} \\
#         \text{max }  &-2x_1+6x_2 \\
#         \text{subject to } & -x_1 + 3x_2 \leq 9 \\
#          & x_1 + x_2 \leq 6 \\
#          & x_1, x_2\geq 0
#     \end{align}
# $$
#
# Answer the following questions.

# %% [markdown]
# 1. Find the optimal solution of $(P_1)$ using the graphical interpretation of the simplex method.

# %% [markdown]
# 2. Code $(P_1)$ in Julia and solve it to verify that you have indeed found the optimal solution.
